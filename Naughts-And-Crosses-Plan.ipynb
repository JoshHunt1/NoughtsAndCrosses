# %% [markdown]
# # Naughts and Crosses
#
# ## Rules
# You take it in turns to place a peice and you have to get three of your own shapes next to eachother to win.
#
# ## Plan
# ### A
# some of the constants i will use are:
# - TOPRIGHT
# - TOPMIDDLE
# - TOPRIGHT
# - LEFT
# - MIDDLE
# - RIGHT
# - BOTTOMLEFT
# - BOTTOMMIDDLE
# - BOTTOMRIGHT
# - PLAYER1
# - PLAYER2
# - X
# - O
#
#          _1_|_2_|_3_
#          _4_|_5_|_6_
#           7 | 8 | 9
#
# the possible winning combinations would be:
# - 1, 2, 3
# - 4, 5, 6
# - 7, 8, 9
# - 1, 4, 7
# - 2, 5, 8
# - 3, 6, 9
# - 1, 5, 9
# - 3, 5, 7
#
# ### B
# the files and structures i would use, would be:
# - in 2D arrays every value is the same
# list = [" "]*10
#
# ### C
# how they will interact, will be questions the program will ask, for example "its player (1 or 2)' go ,where would you like to go?"
#
# and they will type in what number (from 1 to 9) they would like to place their 'X' or 'O'
#
# ## Algorithm
# ![image.png](attachment:image.png)
#
#
# ## Test Plan
# ![graph%20thing.PNG](attachment:graph%20thing.PNG)
